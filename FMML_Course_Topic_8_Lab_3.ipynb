# %% [markdown]
# <a href="https://colab.research.google.com/github/Saikumarpagoti/FMML-MODULUS--IIIT-HYDERABAD/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 05:46:53--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   151MB/s    in 0.5s
#
# 2024-03-26 05:46:57 (151 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23811   1406.6273v1  View synthesis is a process for generating nov...    cs
# 40603   1104.5150v1  In wireless access network optimization, today...    cs
# 22570  1701.02967v1  In this article, a large dimensional performan...  stat
# 22356  1603.03972v2  Manifold learning and dimensionality reduction...  stat
# 4722    1408.2045v1  Given a point set S and an unknown metric d on...    cs
# ...             ...                                                ...   ...
# 29242  1708.08325v1  DeepPrior is a simple approach based on Deep L...    cs
# 30440  1712.02051v1  Modern neural image captioning systems typical...    cs
# 2849   1802.08235v1  A novel Neural Network architecture is propose...    cs
# 26673  1611.06026v1  Person Re-Identification (re-id) is a challeng...    cs
# 31968   0909.3609v1  We propose a randomized algorithm for training...    cs
#
#                                                    title  year  \
# 23811  Image Completion for View Synthesis Using Mark...  2014
# 40603  File Transfer Application For Sharing Femto Ac...  2011
# 22570  A Large Dimensional Analysis of Least Squares ...  2017
# 22356  Laplacian Eigenmaps from Sparse, Noisy Similar...  2016
# 4722   Efficient Clustering with Limited Distance Inf...  2014
# ...                                                  ...   ...
# 29242  DeepPrior++: Improving Fast and Accurate 3D Ha...  2017
# 30440  Show-and-Fool: Crafting Adversarial Examples f...  2017
# 2849                  Vector Field Based Neural Networks  2018
# 26673  Cross Domain Knowledge Transfer for Person Re-...  2016
# 31968         Randomized Algorithms for Large scale SVMs  2009
#
#                                                 keywords
# 23811  [synthesis, generating, important, application...
# 40603  [optimization, challenges, improvement, operat...
# 22570  [dimensional, performance, assumption, dimensi...
# 22356  [dimensionality, reduction, techniques, ubiqui...
# 4722   [efficiently, partitioning, distances, distanc...
# ...                                                  ...
# 29242  [deepprior, locations, publication, outperform...
# 30440  [captioning, typically, framework, consisting,...
# 2849   [architecture, mathematically, physically, non...
# 26673  [identification, challenging, especially, iden...
# 31968  [randomized, algorithm, projections, combinato...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23811    [synthesis, generating, important, application...
# 40603    [optimization, challenges, improvement, operat...
# 22570    [dimensional, performance, assumption, dimensi...
# 22356    [dimensionality, reduction, techniques, ubiqui...
# 4722     [efficiently, partitioning, distances, distanc...
#                                ...
# 22660    [development, tomography, reconstruction, sign...
# 21929    [estimation, functions, important, scintigraph...
# 27410    [benchmark, available, scenarios, annotated, s...
# 37624    [complicated, kinematic, equations, effective,...
# 2436     [probability, distribution, continuous, variab...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8708 words.
# Out of those 4530 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1fd06304-8b7f-487e-a545-314cac094fa6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1fd06304-8b7f-487e-a545-314cac094fa6")) {                    Plotly.newPlot(                        "1fd06304-8b7f-487e-a545-314cac094fa6",                        [{"x":["synthesized","algorithms","generated","algorithm","completion","generating","inpainting","generation","significant","important","background","information","efficient","conversion","applications","synthesis","production","improvement","demonstrate","propagation","plausible","challenges","providers","addresses","necessary","interested","connections","distributed","questions","customers","maximizing","incomplete","problematic","equilibrium","strategies","localized","optimization","triggered","application","operators","supported","respectively","connection","increasing","following","requested","equipment","reasonable","considering","surprisingly","dimension","theoretical","particular","mechanism","explicitly","converges","dimensional","understanding","gaussianity","assumption","performance","reduction","approximation","experimental","laplacian","similarities","synthetic","techniques","investigate","occlusion","processing","computational","eigenmaps","measurements","procedures","resources","regularization","computationally","corrupted","similarity","embedding","dimensionality","expensive","ubiquitous","representations","embeddings","experimentally","neuroscience","assumptions","explorations","engineering","uncorrupted","efficiently","partitioning","clusterings","structure","clustering","classification","distances","empirical","triangulation","extraction","comparative","extracting","experiments","implemented","performed","modalities","advantage","concatenation","different","comparison","databases","independent","fingerprint","compatible","conducted","biometrics","inference","compression","transmitting","industrial","approaches","importantly","deploying","variational","increasingly","restrictive","variables","selection","confirming","classical","ascending","introduced","importance","statistical","introduction","contribution","interpretation","methodological","perspective","regression","proposing","explanatory","complementary","prediction","descriptions","incorporating","potential","alleviate","threefold","awareness","struggling","probabilistic","including","filtering","additional","supervised","downstream","ecosystem","continuous","targeting","predictive","histories","specifically","introduce","recommendations","available","represents","significantly","iterations","unrealistic","divergences","requirements","knowledge","essentially","architectures","candidate","simulated","substantially","characterization","estimation","iterative","densities","accompanying","convergence","exponential","proceeding","influenced","exploiting","utilizing","probability","proportions","illustrate","represent","documents","collocation","represented","generative","representation"],"y":[10,604,177,835,34,114,5,137,236,362,77,675,429,14,411,42,15,159,549,78,32,109,6,61,79,33,45,89,60,10,26,39,9,17,97,16,330,5,262,39,24,94,36,101,90,2,5,34,67,38,69,164,297,109,71,33,177,152,1,81,892,105,112,384,9,33,142,374,137,37,291,323,0,47,50,60,83,95,13,151,97,56,64,16,243,64,62,9,76,5,55,1,146,16,7,308,146,513,32,143,5,131,41,62,591,101,136,18,102,4,771,128,43,127,7,15,75,7,232,45,0,24,442,18,9,49,61,8,118,158,4,105,1,126,80,157,27,82,61,4,74,114,20,2,33,201,42,56,161,34,2,5,2,158,252,66,127,199,11,7,100,10,44,4,169,303,21,326,48,224,33,6,7,49,379,20,118,51,57,42,31,225,64,8,2,119,54,4,7,72,32,173,5,65,121,68,2,78,118,365],"type":"bar"},{"x":["synthesized","algorithms","generated","algorithm","completion","genera ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4530,), (4530, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7991666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Separable</span> <span style=''>Cosparse</span> <span style=''>Analysis</span> <span style=''>Operator</span> <span style=''>Learning</span> <br/><br/><span style=''>The</span> <span style=''>ability</span> <span style=''>of</span> <span style=''>having</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.38783269961977185);'>representation</span> <span style=''>for</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>class</span> <span style=''>of</span> <span style=''>signals</span> <span style=''>has</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.45864661654135336);'>processing</span> <span style=''>and</span> <span style=''>other</span> <span style=''>research</span> <span style=''>fields</span> <span style=''>Among</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.4127906976744186);'>representations</span> <span style=''>the</span> <span style=''>cosparse</span> <span style=''>analysis</span> <span style=''>model</span> <span style=''>has</span> <span style=''>recently</span> <span style=''>gained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style=''>interest</span> <span style=''>Many</span> <span style=''>signals</span> <span style=''>exhibit</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multidimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>eg</span> <span style=''>images</span> <span style=''>or</span> <span style=''>three</span> <span style='background-color:rgba(255, 0, 0, 0.3516483516483517);'>dimensional</span> <span style=''>MRI</span> <span style=''>scans</span> <span style=''>Most</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>vectorized</span> <span style=''>signals</span> <span style=''>and</span> <span style=''>thereby</span> <span style=''>do</span> <span style=''>not</span> <span style=''>account</span> <span style=''>for</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>The</span> <span style=''>drawback</span> <span style=''>of</span> <span style=''>not</span> <span style=''>taking</span> <span style=''>the</span> <span style=''>inherent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>into</span> <span style=''>account</span> <span style=''>is</span> <span style=''>a</span> <span style=''>dramatic</span> <span style=''>increase</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>cosparse</span> <span style=''>Analysis</span> <span style=''>Operator</span> <span style=''>that</span> <span style=''>adheres</span> <span style=''>to</span> <span style=''>the</span> <span style=''>preexisting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>a ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>MedLDA</span> <span style=''>A</span> <span style=''>General</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>of</span> <span style=''>Maximum</span> <span style=''>Margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style=''>Topic</span> <span style=''>Models</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>utilize</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>documents</span> <span style=''>side</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>documents</span> <span style=''>Existing</span> <span style=''>models</span> <span style=''>apply</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>max</span> <span style=''>margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>for</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>categorical</span> <span style=''>response</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discrimination</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>allocation</span> <span style=''>(MedLDA)</span> <span style=''>utilizes</span> <span style=''>the</span> <span style=''>max</span> <span style=''>margin</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>to</span> <span style=''>train</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>and</span> <span style=''>estimate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>topic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>that</span> <span style=''>are</span> <span style=''>arguably</span> <span style=''>more</span> <span style=''>suitable</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>tasks</span> <span style=''>The</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principle</span> <span style=''>of</span> <span style=''>MedLDA</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>joint</span> <span style=''>max</span> <span style=''>margin</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>maximum</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3276231263383297);'>Statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>through</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modelling</span> <br/><br/><span style=''>Usually</span> <span style=''>one</span> <span style=''>compares</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>via</span> <span style=''>null</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significance</span> <span style=''>tests</span> <span style=''>(nhst)</span> <span style=''>Yet</span> <span style=''>the</span> <span style=''>nhst</span> <span style=''>tests</span> <span style=''>suffer</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>shortcomings</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>overcome</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>switching</span> <span style=''>to</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>testing</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>model</span> <span style=''>which</span> <span style=''>jointly</span> <span style=''>analyzes</span> <span style=''>the</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>results</span> <span style=''>obtained</span> <span style=''>by</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>on</span> <span style=''>multiple</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>It</span> <span style=''>returns</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.595959595959596);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5238095238095238);'>accuracies</span> <span style=''>of</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>being</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style='background-color:rgba(0, 255, 0, 0.353819139596137);'>different</span> <span style=''>A</span> <span style=''>further</span> <span style=''>strength</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>model</span> <span style=''>is</span> <span style=''>that</span> <span style=''>by</span> <span style=''>jointly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analyzing</span> <span style=''>the</span> <span style=''>results</span> <span style=''>obtained</span> <span style=''>on</span> <span style=''>all</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>it</span> <span style=''>reduces</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Weakly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style=''>One</span> <span style=''>Shot</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Attention</span> <span style=''>Siamese</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style=''>weakly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>one</span> <span style=''>shot</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>In</span> <span style=''>this</span> <span style=''>task</span> <span style=''>we</span> <span style=''>attempt</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>task</span> <span style=''>over</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>unseen</span> <span style=''>classes</span> <span style=''>when</span> <span style=''>training</span> <span style=''>only</span> <span style=''>using</span> <span style=''>weak</span> <span style=''>binary</span> <span style=''>labels</span> <span style=''>that</span> <span style=''>indicate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>existence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>class</span> <span style=''>instance</span> <span style=''>in</span> <span style=''>a</span> <span style=''>given</span> <span style=''>example</span> <span style=''>The</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditioned</span> <span style=''>on</span> <span style=''>a</span> <span style=''>single</span> <span style=''>exemplar</span> <span style=''>of</span> <span style=''>an</span> <span style=''>unseen</span> <span style=''>class</span> <span style=''>and</span> <span style=''>a</span> <span style=''>target</span> <span style=''>example</span> <span style=''>that</span> <span style=''>may</span> <span style=''>or</span> <span style=''>may</span> <span style=''>not</span> <span style=''>contain</span> <span style=''>an</span> <span style=''>instance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>same</span> <span style=''>class</span> <span style=''>as</span> <span style=''>the</span> <span style=''>exemplar</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>map</span> <span style=''>is</span> <span style=''>computed</span> <span style=''>by</span> <span style=''>using</span> <span style=''>a</span> <span style=''>Siamese</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>to</span> <span style=''>map</span> <span style=''>the</span> <span style=''>exemplar</span> <span style=''>and</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>target</span> <span style=''>example</span> <span style=''>to</span> <span style=''>a</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>space</span> <span style=''>and</span> <span style=''>then</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>cosine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarity</span> <span style=''>scores</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanism</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10400285918513223)
# 	experimental (0.13724088634739098)
# 	architecture (0.08684774839170836)
# 	information (0.24124374553252323)
# 	knowledge (0.13545389563974267)
# 	segmentation (0.0825589706933524)
# 	detection (0.11722659042172981)
# 	convolutional (0.13652609006433167)
# 	recognition (0.1343817012151537)
# 	different (0.27555396711937097)
#
# Some Statistics words are:
# 	stochastic (0.13236763236763235)
# 	estimation (0.17082917082917082)
# 	algorithm (0.3926073926073926)
# 	variables (0.13836163836163837)
# 	statistical (0.15484515484515485)
# 	distribution (0.16983016983016982)
# 	inference (0.19480519480519481)
# 	theoretical (0.17182817182817184)
# 	dimensional (0.18431568431568432)
# 	regression (0.1928071928071928)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="272d7d22-8640-49c3-8e0e-65790a0797c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("272d7d22-8640-49c3-8e0e-65790a0797c5")) {                    Plotly.newPlot(                        "272d7d22-8640-49c3-8e0e-65790a0797c5",                        [{"x":["synthesized","algorithms","generated","algorithm","completion","generating","inpainting","generation","significant","important","background","information","efficient","conversion","applications","synthesis","production","improvement","demonstrate","propagation","plausible","challenges","providers","addresses","necessary","interested","connections","distributed","questions","customers","maximizing","incomplete","problematic","equilibrium","strategies","localized","optimization","triggered","application","operators","supported","respectively","connection","increasing","following","requested","equipment","reasonable","considering","surprisingly","dimension","theoretical","particular","mechanism","explicitly","converges","dimensional","understanding","gaussianity","assumption","performance","reduction","approximation","experimental","laplacian","similarities","synthetic","techniques","investigate","occlusion","processing","computational","eigenmaps","measurements","procedures","resources","regularization","computationally","corrupted","similarity","embedding","dimensionality","expensive","ubiquitous","representations","embeddings","experimentally","neuroscience","assumptions","explorations","engineering","uncorrupted","efficiently","partitioning","clusterings","structure","clustering","classification","distances","empirical","triangulation","extraction","comparative","extracting","experiments","implemented","performed","modalities","advantage","concatenation","different","comparison","databases","independent","fingerprint","compatible","conducted","biometrics","inference","compression","transmitting","industrial","approaches","importantly","deploying","variational","increasingly","restrictive","variables","selection","confirming","classical","ascending","introduced","importance","statistical","introduction","contribution","interpretation","methodological","perspective","regression","proposing","explanatory","complementary","prediction","descriptions","incorporating","potential","alleviate","threefold","awareness","struggling","probabilistic","including","filtering","additional","supervised","downstream","ecosystem","continuous","targeting","predictive","histories","specifically","introduce","recommendations","available","represents","significantly","iterations","unrealistic","divergences","requirements","knowledge","essentially","architectures","candidate","simulated","substantially","characterization","estimation","iterative","densities","accompanying","convergence","exponential","proceeding","influenced","exploiting","utilizing","probability","proportions","illustrate","represent","documents","collocation","represented","generative","representation","specialized","alternatives","dissimilarities","relationship","dissimilarity","inexpensive","generalize","therefore","concerned","competitive","ambiguous","definitions","individual","objective","constraint","alternative","functions","theoretic","independently","separated","evaluated","switching","constrained","interpolate","favorably","evaluation","promising","decoupled","computation","evaluations","direction","criterion","balancing","acquisition","rationality","effective","adaptively","framework","contributions","constraints","distribution","discriminator","minimizing","generalization","generator","adversarial","optimizing","nonparametric","statistic","comparisons","hypothesis","goodfellow","discrepancy","informally","tran ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	eigenmaps
# 	transmitting
# 	decoupled
# 	elliptical
# 	volatility
# 	expectimax
# 	nonparanormal
# 	spearmans
# 	reparametrization
# 	subsampling
# 	logitboost
# 	robustifying
# 	inspecting
# 	sparsities
# 	endogenous
# 	blackwellized
# 	kolmogorov
# 	discretisation
# 	chemometrics
# 	continuing
# Some words which never appear in Statistics papers:
# 	requested
# 	concatenation
# 	struggling
# 	ecosystem
# 	collocation
# 	neurophysiological
# 	propositional
# 	compliant
# 	tokenizer
# 	recognizer
# 	extraordinarily
# 	quantifies
# 	generalizable
# 	hypernymy
# 	centrally
# 	supervising
# 	monocular
# 	visibility
# 	specifications
# 	photometric

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075976622577668e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
